# %%
import torch 
from torch_geometric.data import Data, HeteroData

# %%
d = Data()
d.num_nodes = 10 
d.edge_index = torch.tensor([[0, 1], [1,2]])

d.num_nodes
# Out:
# 10

# %%
d = HeteroData()
d['a', 'b', 'c'].edge_index = torch.tensor([[0, 1, 2], [1, 2, 0]])

d.edge_index_dict
# Out:
# {('a',
#   'b',
#   'c'): tensor([[0, 1, 2],
#          [1, 2, 0]])}
